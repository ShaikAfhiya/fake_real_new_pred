# %%
import pandas as pd
import numpy as np
import joblib

# %%
true_news=pd.read_csv('True.csv')
true_news
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
true_news.drop('date',axis=1,inplace=True)

# %%
true_news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# dtype: int64

# %%
fake_news=pd.read_csv('Fake.csv')
fake_news
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
fake_news.drop('date',axis=1,inplace=True)

# %%
fake_news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# dtype: int64

# %%
fake_news['label']=0
true_news['label']=1
df=pd.concat([fake_news,true_news],axis=0)
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.to_csv("news_dataset.csv", index=False)
df=pd.read_csv('news_dataset.csv')
df
# Out:
#                                                    title  \
# 0       House Republicans Forcing Fetal Tissue Resear...
# 1       BREAKING: Donald Trump Walked Into Dressing R...
# 2          Turkish capital bans LGBT cinema, exhibitions
# 3      Kuwait orders North Korea's ambassador to leav...
# 4      Sudan disappointed at renewal of U.S. travel b...
# ...                                                  ...
# 44893  Canada foreign minister will oppose U.S. borde...
# 44894  LISTEN TO THIS MEMBER OF CONGRESS WHINE ABOUT ...
# 44895  Republicans Rubio, Cruz release taxes, piling ...
# 44896   WATCH: Fox Business Misses The Days Of Child ...
# 44897  OBAMA’S GAL PAL Loretta Lynch WON’T RECUSE HER...
#
#                                                     text       subject  label
# 0      Using the long-debunked Planned Parenthood vid...          News      0
# 1      Not only is Donald Trump an admitted serial gr...          News      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   label    44898 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#               label
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
#!pip install nltk

# %%
#!pip show nltk

# %%
import nltk

# %%
from nltk.corpus import stopwords

# %%
stop_words=stopwords.words('english')
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
import re
#from nltk.stem import PorterStemmer
#stemmer=PorterStemmer()
def formatted_text(text):
      clean_text=re.sub(r'[^a-zA-Z]',' ',text)
      words=clean_text.lower().split()
      words=[word for word in words if word not in stop_words]
      return ' '.join(words)
df['formatted_text']=df['text'].apply(formatted_text)

# %%
df.drop('text',axis=1)
# Out:
#                                                    title       subject  label  \
# 0       House Republicans Forcing Fetal Tissue Resear...          News      0
# 1       BREAKING: Donald Trump Walked Into Dressing R...          News      0
# 2          Turkish capital bans LGBT cinema, exhibitions     worldnews      1
# 3      Kuwait orders North Korea's ambassador to leav...     worldnews      1
# 4      Sudan disappointed at renewal of U.S. travel b...  politicsNews      1
# ...                                                  ...           ...    ...
# 44893  Canada foreign minister will oppose U.S. borde...  politicsNews      1
# 44894  LISTEN TO THIS MEMBER OF CONGRESS WHINE ABOUT ...      politics      0
# 44895  Republicans Rubio, Cruz release taxes, piling ...  politicsNews      1
# 44896   WATCH: Fox Business Misses The Days Of Child ...          News      0
# 44897  OBAMA’S GAL PAL Loretta Lynch WON’T RECUSE HER...     left-news      0
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vector=TfidfVectorizer()
x=vector.fit_transform(df['formatted_text'])
y=df['label']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(13470,))

# %%
from sklearn.metrics import accuracy_score,recall_score
y_pred = model.predict(x_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9869339272457313

# %%
print("Recall:", recall_score(y_test, y_pred))
# Out:
# Recall: 0.9879200867275825

# %%
joblib.dump(model, 'fake_real_pkl')
joblib.dump(vector, 'vectorizer_pkl')
print("Model and vectorizer saved!")
# Out:
# Model and vectorizer saved!
